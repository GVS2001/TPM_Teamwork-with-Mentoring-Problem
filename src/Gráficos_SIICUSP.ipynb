# %%
data = [
    (27, 'First_to_find', 'MST', 800991),
    (27, 'First_to_find', 'CR', 800991),
    (27, 'First_to_find', 'MANPOWER', 800990),
    (27, 'First_to_find', 'SPT', 800981),
    (27, 'Farest', 'LPT', 800981),
    (27, 'First_to_find', 'SLACK', 800973),
    (27, 'First_to_find', 'LPT', 800963),
    (27, 'Nearest', 'MANPOWER', 800913),
    (27, 'Farest', 'MANPOWER', 800913),
    (27, 'First_to_find', 'EDD', 800911),
    (28, 'Nearest', 'MST', 769472),
    (28, 'Farest', 'MST', 769472),
    (28, 'Nearest', 'SPT', 769462),
    (28, 'Farest', 'SPT', 769462),
    (28, 'Nearest', 'EDD', 769445),
    (28, 'Farest', 'EDD', 769445),
    (28, 'Nearest', 'SLACK', 769445),
    (28, 'Farest', 'SLACK', 769445),
    (28, 'Nearest', 'CR', 769442),
    (28, 'Farest', 'CR', 769442),
    (28, 'Nearest', 'LPT', 769418),
    (24, 'First_to_find', 'CR', 855630),
    (27, 'First_to_find', 'EDD', 800991),
    (27, 'First_to_find', 'MST', 800991),
    (27, 'First_to_find', 'SLACK', 800991),
    (27, 'First_to_find', 'MANPOWER', 800991),
    (27, 'Farest', 'LPT', 800981),
    (27, 'First_to_find', 'LPT', 800925),
    (27, 'Nearest', 'MANPOWER', 800913),
    (27, 'Farest', 'MANPOWER', 800913),
    (28, 'First_to_find', 'SPT', 788516),
    (28, 'Nearest', 'MST', 769472),
    (28, 'Farest', 'MST', 769472),
    (28, 'Nearest', 'SPT', 769462),
    (28, 'Farest', 'SPT', 769462),
    (28, 'Nearest', 'EDD', 769445),
    (28, 'Farest', 'EDD', 769445),
    (28, 'Nearest', 'SLACK', 769445),
    (28, 'Farest', 'SLACK', 769445),
    (28, 'Nearest', 'CR', 769442),
    (28, 'Farest', 'CR', 769442),
    (28, 'Nearest', 'LPT', 769418),
    (27, 'First_to_find', 'SPT', 800991),
    (27, 'First_to_find', 'EDD', 800991),
    (27, 'First_to_find', 'MST', 800991),
    (27, 'First_to_find', 'CR', 800991),
    (27, 'First_to_find', 'SLACK', 800991),
    (27, 'First_to_find', 'MANPOWER', 800989),
    (27, 'Farest', 'LPT', 800981),
    (27, 'Nearest', 'MANPOWER', 800913),
    (27, 'Farest', 'MANPOWER', 800913),
    (28, 'First_to_find', 'LPT', 779516),
    (28, 'Nearest', 'MST', 769472),
    (28, 'Farest', 'MST', 769472),
    (28, 'Nearest', 'SPT', 769462),
    (28, 'Farest', 'SPT', 769462),
    (28, 'Nearest', 'EDD', 769445),
    (28, 'Farest', 'EDD', 769445),
    (28, 'Nearest', 'SLACK', 769445),
    (28, 'Farest', 'SLACK', 769445),
    (28, 'Nearest', 'CR', 769442),
    (28, 'Farest', 'CR', 769442),
    (28, 'Nearest', 'LPT', 769418)
]

# %%
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict

# %%
# Create a dictionary to store the data for plotting
plot_data = {}
for entry in data:
    key = entry[1]  # Assuming the second element is the category
    if key not in plot_data:
        plot_data[key] = []
    plot_data[key].append(entry[3])  # Assuming the fourth element is the value to plot

# Plot the data
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed

for category, values in plot_data.items():
    plt.bar(category, sum(values), label=category)

plt.xlabel('Category')
plt.ylabel('Total Value')
plt.title('Visualization of Data')
plt.legend()
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility

plt.tight_layout()
plt.show()

# %%
# Create a dictionary to store the data for plotting
plot_data = {}
for entry in data:
    category = entry[1]  # Assuming the second element is the category
    if category not in plot_data:
        plot_data[category] = []
    plot_data[category].append(entry[3])  # Assuming the fourth element is the value to plot

# Extract unique categories
categories = list(plot_data.keys())

# Create a separate bar plot for each category
plt.figure(figsize=(12, 8))

for i, category in enumerate(categories):
    plt.subplot(3, 1, i+1)
    values = plot_data[category]
    x = np.arange(len(values))
    plt.bar(x, values, label=category)
    plt.xlabel('Entry')
    plt.ylabel('Value')
    plt.title(f'Category: {category}')
    plt.xticks(x, [str(j) for j in range(1, len(values)+1)])

plt.tight_layout()
plt.show()

# %%
# Extract the relevant data for plotting
categories = ['First_to_find', 'Farest', 'Nearest']
sections = {category: [] for category in categories}

for entry in data:
    category = entry[1]
    value = entry[3]
    sections[category].append(value)

# Extract unique x values (entry numbers)
x_values = np.arange(1, 8)

# Create a single graph with three sections (categories)
plt.figure(figsize=(12, 6))

for i, category in enumerate(categories):
    plt.bar(x_values + i * 0.2, sections[category][:7], width=0.2, label=category)

plt.xlabel('Entry')
plt.ylabel('Value')
plt.title('Graph with Three Sections (Categories)')
plt.xticks(x_values + 0.2, x_values)
plt.legend()
plt.tight_layout()
plt.show()

# %%
unique_names = set(entry[2] for entry in data)

# Convert the set of unique names to a list
unique_names_list = list(unique_names)

# Print the list of unique names
print(unique_names_list)
# Out:
# ['CR', 'MST', 'SPT', 'MANPOWER', 'LPT', 'SLACK', 'EDD']

# %%
data = [

    (24, 'First_to_find', 'CR', 855630),
    (27, 'First_to_find', 'EDD', 800991),
    (27, 'First_to_find', 'MST', 800991),
    (27, 'First_to_find', 'SLACK', 800991),
    (27, 'First_to_find', 'MANPOWER', 800991),
    (27, 'Farest', 'LPT', 800981),
    (27, 'First_to_find', 'LPT', 800925),
    (27, 'Nearest', 'MANPOWER', 800913),
    (27, 'Farest', 'MANPOWER', 800913),
    (28, 'First_to_find', 'SPT', 788516),
    (28, 'Nearest', 'MST', 769472),
    (28, 'Farest', 'MST', 769472),
    (28, 'Nearest', 'SPT', 769462),
    (28, 'Farest', 'SPT', 769462),
    (28, 'Nearest', 'EDD', 769445),
    (28, 'Farest', 'EDD', 769445),
    (28, 'Nearest', 'SLACK', 769445),
    (28, 'Farest', 'SLACK', 769445),
    (28, 'Nearest', 'CR', 769442),
    (28, 'Farest', 'CR', 769442),
    (28, 'Nearest', 'LPT', 769418)
]

# %%
categories = ['First_to_find', 'Farest', 'Nearest']
heuristics = ['CR', 'MST', 'SPT', 'MANPOWER', 'LPT', 'SLACK', 'EDD']
sections = {category: [] for category in categories}
heu = {category: [] for category in heuristics}

for entry in data:
    category = entry[1]
    value = entry[3]
    sections[category].append(value)

# Extract unique x values (entry numbers)
x_values = np.arange(1, 8)

# Create a single graph with three sections (categories)
plt.figure(figsize=(12, 6))

print(categories)

for i, category in enumerate(categories):
    print(i, category)
    plt.bar(x_values + i * 0.2, sections[category][:7], width=0.2, label=category)

plt.xlabel('Entry')
plt.ylabel('Value')
plt.title('Graph with Three Sections (Categories)')
plt.xticks(x_values + 0.2, x_values)
plt.legend()

# Set the y-axis limits
y_min = 700000  # Set your desired minimum limit here
y_max = 820000  # Set your desired maximum limit here
plt.ylim(y_min, y_max)

plt.tight_layout()
plt.show()
# Out:
# ['First_to_find', 'Farest', 'Nearest']
# 0 First_to_find
# 1 Farest
# 2 Nearest

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the data
data = [
    (24, 'First_to_find', 'CR', 855630),
    (27, 'First_to_find', 'EDD', 800991),
    (27, 'First_to_find', 'MST', 800991),
    (27, 'First_to_find', 'SLACK', 800991),
    (27, 'First_to_find', 'MANPOWER', 800991),
    (27, 'Farest', 'LPT', 800981),
    (27, 'First_to_find', 'LPT', 800925),
    (27, 'Nearest', 'MANPOWER', 800913),
    (27, 'Farest', 'MANPOWER', 800913),
    (28, 'First_to_find', 'SPT', 788516),
    (28, 'Nearest', 'MST', 769472),
    (28, 'Farest', 'MST', 769472),
    (28, 'Nearest', 'SPT', 769462),
    (28, 'Farest', 'SPT', 769462),
    (28, 'Nearest', 'EDD', 769445),
    (28, 'Farest', 'EDD', 769445),
    (28, 'Nearest', 'SLACK', 769445),
    (28, 'Farest', 'SLACK', 769445),
    (28, 'Nearest', 'CR', 769442),
    (28, 'Farest', 'CR', 769442),
    (28, 'Nearest', 'LPT', 769418)
]

# Create a dictionary to store data by heuristic
heuristic_data = {heuristic: {category: [] for category in ['First_to_find', 'Farest', 'Nearest']} for heuristic in ['CR', 'MST', 'SPT', 'MANPOWER', 'LPT', 'SLACK', 'EDD']}

# Iterate through the data and group it by heuristic and category
for entry in data:
    entry_number, category, heuristic, value = entry
    heuristic_data[heuristic][category].append(value)

# Extract unique x values (entry numbers)
x_values = np.arange(1, 8)

# Create a single graph with seven sections (heuristics)
plt.figure(figsize=(12, 6))

for i, heuristic in enumerate(['CR', 'MST', 'SPT', 'MANPOWER', 'LPT', 'SLACK', 'EDD']):
    plt.subplot(7, 1, i + 1)

    for j, category in enumerate(['First_to_find', 'Farest', 'Nearest']):
        x = x_values + j * 0.2
        values = heuristic_data[heuristic][category][:7]
        plt.bar(x, values, width=0.2, label=category)

    plt.xlabel('Entry')
    plt.ylabel('Value')
    plt.title(f'{heuristic} - Grouped by Category')
    plt.xticks(x_values + 0.2 * 2, x_values)
    plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the data
# ... (your data)

categories = ['First_to_find', 'Farest', 'Nearest']
heuristics = ['CR', 'MST', 'SPT', 'MANPOWER', 'LPT', 'SLACK', 'EDD']

# Create dictionaries to store data for each category
category_data = {category: {heuristic: [] for heuristic in heuristics} for category in categories}

# Iterate through the data and group it by category and heuristic
for entry in data:
    category = entry[1]
    heuristic = entry[2]
    value = entry[3]
    if category in categories and heuristic in heuristics:
        category_data[category][heuristic].append(value)

# Extract unique x values (entry numbers)
x_values = np.arange(1, 8)

# Create a single graph with three sections (categories)
plt.figure(figsize=(12, 6))


for i, category in enumerate(categories):
    plt.subplot(3, 1, i + 1)
    for j, heuristic in enumerate(heuristics):
        x = x_values + j * 0.2
        values = category_data[category][heuristic][:7]
        plt.bar(x, values, width=0.2, label=heuristic)

    plt.xlabel('Entry')
    plt.ylabel('Value')
    plt.title(f'{category} - Grouped by Heuristic')
    plt.xticks(x_values + 0.2 * (len(heuristics) - 1), x_values)
    plt.legend()

plt.tight_layout()
plt.show()

# %%
# Extract the relevant data for plotting
categories = ['First_to_find', 'Farest', 'Nearest']
sections = {category: defaultdict(list) for category in categories}

for entry in data:
    category = entry[1]
    value = entry[3]
    section = entry[2]
    sections[category][section].append(value)

# Extract unique x values (entry numbers)
x_values = np.arange(1, 8)

# Create a single graph with three sections (categories)
plt.figure(figsize=(12, 6))

for i, category in enumerate(categories):
    section_names = list(sections[category].keys())
    num_sections = len(section_names)

    plt.subplot(3, 1, i+1)

    x_offset = np.linspace(-0.2, 0.2, num_sections)

    for j, section_name in enumerate(section_names):
        x = x_values + x_offset[j]
        values = sections[category][section_name][:7]
        plt.bar(x, values, width=0.2, label=section_name)

    plt.xlabel('Entry')
    plt.ylabel('Value')
    plt.title(f'{category} - Grouped by Section (Third Column)')
    plt.xticks(x_values, x_values)
    plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-7fbfbb7b6b5f> in <cell line: 17>()
#      26         x = x_values + x_offset[j]
#      27         values = sections[category][section_name][:7]
# ---> 28         plt.bar(x, values, width=0.2, label=section_name)
#      29
#      30     plt.xlabel('Entry')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2437         x, height, width=0.8, bottom=None, *, align='center',
#    2438         data=None, **kwargs):
# -> 2439     return gca().bar(
#    2440         x, height, width=width, bottom=bottom, align=align,
#    2441         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
import matplotlib.pyplot as plt

# Define the data with commas
data = [
    (27, 'First_to_find', 'MST', 800991),
    (27, 'First_to_find', 'CR', 800991),
    (27, 'First_to_find', 'MANPOWER', 800990),
    (27, 'First_to_find', 'SPT', 800981),
    (27, 'Farest', 'LPT', 800981),
    (27, 'First_to_find', 'SLACK', 800973),
    (27, 'First_to_find', 'LPT', 800963),
    (27, 'Nearest', 'MANPOWER', 800913),
    (27, 'Farest', 'MANPOWER', 800913),
    (27, 'First_to_find', 'EDD', 800911),
    (28, 'Nearest', 'MST', 769472),
    (28, 'Farest', 'MST', 769472),
    (28, 'Nearest', 'SPT', 769462),
    (28, 'Farest', 'SPT', 769462),
    (28, 'Nearest', 'EDD', 769445),
    (28, 'Farest', 'EDD', 769445),
    (28, 'Nearest', 'SLACK', 769445),
    (28, 'Farest', 'SLACK', 769445),
    (28, 'Nearest', 'CR', 769442),
    (28, 'Farest', 'CR', 769442),
    (28, 'Nearest', 'LPT', 769418),
    (24, 'First_to_find', 'CR', 855630),
    (27, 'First_to_find', 'EDD', 800991),
    (27, 'First_to_find', 'MST', 800991),
    (27, 'First_to_find', 'SLACK', 800991),
    (27, 'First_to_find', 'MANPOWER', 800991),
    (27, 'Farest', 'LPT', 800981),
    (27, 'First_to_find', 'LPT', 800925),
    (27, 'Nearest', 'MANPOWER', 800913),
    (27, 'Farest', 'MANPOWER', 800913),
    (28, 'First_to_find', 'SPT', 788516),
    (28, 'Nearest', 'MST', 769472),
    (28, 'Farest', 'MST', 769472),
    (28, 'Nearest', 'SPT', 769462),
    (28, 'Farest', 'SPT', 769462),
    (28, 'Nearest', 'EDD', 769445),
    (28, 'Farest', 'EDD', 769445),
    (28, 'Nearest', 'SLACK', 769445),
    (28, 'Farest', 'SLACK', 769445),
    (28, 'Nearest', 'CR', 769442),
    (28, 'Farest', 'CR', 769442),
    (28, 'Nearest', 'LPT', 769418),
    (27, 'First_to_find', 'SPT', 800991),
    (27, 'First_to_find', 'EDD', 800991),
    (27, 'First_to_find', 'MST', 800991),
    (27, 'First_to_find', 'CR', 800991),
    (27, 'First_to_find', 'SLACK', 800991),
    (27, 'First_to_find', 'MANPOWER', 800989),
    (27, 'Farest', 'LPT', 800981),
    (27, 'Nearest', 'MANPOWER', 800913),
    (27, 'Farest', 'MANPOWER', 800913),
    (28, 'First_to_find', 'LPT', 779516),
    (28, 'Nearest', 'MST', 769472),
    (28, 'Farest', 'MST', 769472),
    (28, 'Nearest', 'SPT', 769462),
    (28, 'Farest', 'SPT', 769462),
    (28, 'Nearest', 'EDD', 769445),
    (28, 'Farest', 'EDD', 769445),
    (28, 'Nearest', 'SLACK', 769445),
    (28, 'Farest', 'SLACK', 769445),
    (28, 'Nearest', 'CR', 769442),
    (28, 'Farest', 'CR', 769442),
    (28, 'Nearest', 'LPT', 769418)
]

# Create a dictionary to store the data for plotting
plot_data = {}
for entry in data:
    key = entry[1]  # Assuming the second element is the category
    if key not in plot_data:
        plot_data[key] = []
    plot_data[key].append(entry[3])  # Assuming the fourth element is the value to plot

# Plot the data
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed

for category, values in plot_data.items():
    plt.bar(category, sum(values), label=category)

plt.xlabel('Category')
plt.ylabel('Total Value')
plt.title('Visualization of Data')
plt.legend()
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility

plt.tight_layout()
plt.show()

# %%
def barplot_results_from_evaluate(dataX):

  text_ylabel = 'Loss'
  text_title = 'Loss para os 6 modelos com as 3 bases de teste para cada'
  loc='upper right'
  colors = ['lightcoral', 'darkorange', 'red']

  categories = ['First_to_find', 'Farest', 'Nearest']
  heuristics = ['CR', 'MST', 'SPT', 'MANPOWER', 'LPT', 'SLACK', 'EDD']

  #define os valores das labels (em baixo do eixo x) por 'bases_de_dados' e define os valores os valores das barras por 'bases_de_testes'
  bases_de_dados = set(heuristics)

  bases_de_testes = {heuristic: [] for heuristic in heuristics}

  # Iterate through the data and group it by heuristic
  for entry in data:
    heuristic = entry[2]
    if heuristic in heuristics:
        bases_de_testes[heuristic].append(entry)

  #transforma os valores em float com 3 casas decimais
  bases_de_testes = {
      key: tuple(float(format(value, '.3f')) for value in values)
      for key, values in bases_de_testes.items()
  }

  #configuração de alguns parâmeotros extras para o gráfico
  x = np.arange(len(bases_de_dados))
  width = 0.25
  multiplier = 0
  i=0

  #define a figura e os eixos, junto com o tamanho e disposição do gráfico
  fig, ax = plt.subplots(layout='constrained', figsize=(10, 5))

  #configura as diversas barras do gráfico
  for attribute, measurement in bases_de_testes.items():
      COLOR = colors[i]
      if(i==3):
        i=0
      else:
        i+=1
      offset = width * multiplier
      rects = ax.bar(x + offset, measurement, width, label=attribute, color=COLOR)
      ax.bar_label(rects, padding=3)
      multiplier += 1

  # Adicionando algum texto para rótulos, título e rótulos personalizados do eixo x
  ax.set_ylabel(text_ylabel)
  ax.set_title(text_title)
  ax.set_xticks(x + width, bases_de_dados)
  ax.legend(loc=loc)

  #Plotando a imagem final
  plt.show()

# %%
data = [
    (24, 'First_to_find', 'CR', 855630),
    (27, 'First_to_find', 'EDD', 800991),
    (27, 'First_to_find', 'MST', 800991),
    (27, 'First_to_find', 'SLACK', 800991),
    (27, 'First_to_find', 'MANPOWER', 800991),
    (27, 'Farest', 'LPT', 800981),
    (27, 'First_to_find', 'LPT', 800925),
    (27, 'Nearest', 'MANPOWER', 800913),
    (27, 'Farest', 'MANPOWER', 800913),
    (28, 'First_to_find', 'SPT', 788516),
    (28, 'Nearest', 'MST', 769472),
    (28, 'Farest', 'MST', 769472),
    (28, 'Nearest', 'SPT', 769462),
    (28, 'Farest', 'SPT', 769462),
    (28, 'Nearest', 'EDD', 769445),
    (28, 'Farest', 'EDD', 769445),
    (28, 'Nearest', 'SLACK', 769445),
    (28, 'Farest', 'SLACK', 769445),
    (28, 'Nearest', 'CR', 769442),
    (28, 'Farest', 'CR', 769442),
    (28, 'Nearest', 'LPT', 769418)
]

# Create a dictionary with keys based on the second and third columns
data_dict = {}

for item in data:
    second_column = item[1]
    third_column = item[2]
    value = item[3]

    if (second_column, third_column) not in data_dict:
        data_dict[(second_column, third_column)] = []

    data_dict[(second_column, third_column)].append(value)

# Print the resulting dictionary
print(data_dict)

# Extract data where the second column is 'First_to_find'
filtered_data = [item for item in data if item[1] == 'First_to_find']

# Create lists for x (third_column) and y (value) values
x_values = [item[2] for item in filtered_data]
y_values = [item[3] for item in filtered_data]

# Create the bar plot
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.bar(x_values, y_values)
plt.xlabel('Third Column')
plt.ylabel('Value')
plt.title('Bar Plot for Data with Second Column as "First_to_find"')
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility if needed
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# {('First_to_find', 'CR'): [855630], ('First_to_find', 'EDD'): [800991], ('First_to_find', 'MST'): [800991], ('First_to_find', 'SLACK'): [800991], ('First_to_find', 'MANPOWER'): [800991], ('Farest', 'LPT'): [800981], ('First_to_find', 'LPT'): [800925], ('Nearest', 'MANPOWER'): [800913], ('Farest', 'MANPOWER'): [800913], ('First_to_find', 'SPT'): [788516], ('Nearest', 'MST'): [769472], ('Farest', 'MST'): [769472], ('Nearest', 'SPT'): [769462], ('Farest', 'SPT'): [769462], ('Nearest', 'EDD'): [769445], ('Farest', 'EDD'): [769445], ('Nearest', 'SLACK'): [769445], ('Farest', 'SLACK'): [769445], ('Nearest', 'CR'): [769442], ('Farest', 'CR'): [769442], ('Nearest', 'LPT'): [769418]}

# %%
import matplotlib.pyplot as plt
import numpy as np

data = [
    (24, 'First_to_find', 'CR', 855630),
    (27, 'First_to_find', 'EDD', 800991),
    (27, 'First_to_find', 'MST', 800991),
    (27, 'First_to_find', 'SLACK', 800991),
    (27, 'First_to_find', 'MANPOWER', 800991),
    (27, 'Farest', 'LPT', 800981),
    (27, 'First_to_find', 'LPT', 800925),
    (27, 'Nearest', 'MANPOWER', 800913),
    (27, 'Farest', 'MANPOWER', 800913),
    (28, 'First_to_find', 'SPT', 788516),
    (28, 'Nearest', 'MST', 769472),
    (28, 'Farest', 'MST', 769472),
    (28, 'Nearest', 'SPT', 769462),
    (28, 'Farest', 'SPT', 769462),
    (28, 'Nearest', 'EDD', 769445),
    (28, 'Farest', 'EDD', 769445),
    (28, 'Nearest', 'SLACK', 769445),
    (28, 'Farest', 'SLACK', 769445),
    (28, 'Nearest', 'CR', 769442),
    (28, 'Farest', 'CR', 769442),
    (28, 'Nearest', 'LPT', 769418)
]

# Create a dictionary to group data by the second column
data_dict = {}
for item in data:
    second_column = item[1]
    if second_column not in data_dict:
        data_dict[second_column] = []
    data_dict[second_column].append((item[2], item[3]))

# Extract x and y values for each category
categories = list(data_dict.keys())
x_values = [item[0] for item in data_dict['First_to_find']]
y_values_first = [item[1] for item in data_dict['First_to_find']]
y_values_farest = [item[1] for item in data_dict['Farest']]
y_values_nearest = [item[1] for item in data_dict['Nearest']]

# Create the bar plot
bar_width = 0.2
index = np.arange(len(x_values))
plt.figure(figsize=(12, 6))

plt.bar(index - bar_width, y_values_first, bar_width, label='First_to_find')
plt.bar(index, y_values_farest, bar_width, label='Farest')
plt.bar(index + bar_width, y_values_nearest, bar_width, label='Nearest')

plt.xlabel('Third Column')
plt.ylabel('Value')
plt.title('Bar Plot for Different Categories')
plt.xticks(index, x_values)
plt.legend(loc=4)
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data = [
    (24, 'First_to_find', 'CR', 855630),
    (27, 'First_to_find', 'EDD', 800991),
    (27, 'First_to_find', 'MST', 800991),
    (27, 'First_to_find', 'SLACK', 800991),
    (27, 'First_to_find', 'MANPOWER', 800991),
    (27, 'Farest', 'LPT', 800981),
    (27, 'First_to_find', 'LPT', 800925),
    (27, 'Nearest', 'MANPOWER', 800913),
    (27, 'Farest', 'MANPOWER', 800913),
    (28, 'First_to_find', 'SPT', 788516),
    (28, 'Nearest', 'MST', 769472),
    (28, 'Farest', 'MST', 769472),
    (28, 'Nearest', 'SPT', 769462),
    (28, 'Farest', 'SPT', 769462),
    (28, 'Nearest', 'EDD', 769445),
    (28, 'Farest', 'EDD', 769445),
    (28, 'Nearest', 'SLACK', 769445),
    (28, 'Farest', 'SLACK', 769445),
    (28, 'Nearest', 'CR', 769442),
    (28, 'Farest', 'CR', 769442),
    (28, 'Nearest', 'LPT', 769418)
]

# Create a dictionary to group data by the second column
data_dict = {}
for item in data:
    second_column = item[1]
    if second_column not in data_dict:
        data_dict[second_column] = []
    data_dict[second_column].append((item[2], item[3]))

# Define the x-values and categories
x_values = ['First_to_find', 'Farest', 'Nearest']
categories = ['CR', 'MST', 'SPT', 'MANPOWER', 'LPT', 'SLACK', 'EDD']

# Create the bar plot
bar_width = 0.2
index = np.arange(len(x_values))
plt.figure(figsize=(12, 6))

for i, x_value in enumerate(x_values):
    y_values = [item[1] for item in data_dict[x_value]]
    values = [item[1] for item in data_dict[x_value]]

    plt.bar(index + i * bar_width, values, bar_width, label=x_value)

plt.xlabel('Third Column')
plt.ylabel('Value')
plt.title('Bar Plot for Different Categories')
plt.xticks(index + bar_width, categories, rotation=45)  # Rotate x-axis labels
plt.legend()
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-d925435d0e20> in <cell line: 45>()
#      47     values = [item[1] for item in data_dict[x_value]]
#      48
# ---> 49     plt.bar(index + i * bar_width, values, bar_width, label=x_value)
#      50
#      51 plt.xlabel('Third Column')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2437         x, height, width=0.8, bottom=None, *, align='center',
#    2438         data=None, **kwargs):
# -> 2439     return gca().bar(
#    2440         x, height, width=width, bottom=bottom, align=align,
#    2441         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

data = [
    (24, 'First_to_find', 'CR', 855630),
    (27, 'First_to_find', 'EDD', 800991),
    (27, 'First_to_find', 'MST', 800991),
    (27, 'First_to_find', 'SLACK', 800991),
    (27, 'First_to_find', 'MANPOWER', 800991),
    (27, 'Farest', 'LPT', 800981),
    (27, 'First_to_find', 'LPT', 800925),
    (27, 'Nearest', 'MANPOWER', 800913),
    (27, 'Farest', 'MANPOWER', 800913),
    (28, 'First_to_find', 'SPT', 788516),
    (28, 'Nearest', 'MST', 769472),
    (28, 'Farest', 'MST', 769472),
    (28, 'Nearest', 'SPT', 769462),
    (28, 'Farest', 'SPT', 769462),
    (28, 'Nearest', 'EDD', 769445),
    (28, 'Farest', 'EDD', 769445),
    (28, 'Nearest', 'SLACK', 769445),
    (28, 'Farest', 'SLACK', 769445),
    (28, 'Nearest', 'CR', 769442),
    (28, 'Farest', 'CR', 769442),
    (28, 'Nearest', 'LPT', 769418)
]

# Create a dictionary to group data by the second column
data_dict = {}
for item in data:
    second_column = item[1]
    if second_column not in data_dict:
        data_dict[second_column] = []
    data_dict[second_column].append((item[2], item[3]))

# Extract x and y values for each category
categories = list(data_dict.keys())
x_values = [item[0] for item in data_dict['First_to_find']]
y_values_first = [item[1] for item in data_dict['First_to_find']]
y_values_farest = [item[1] for item in data_dict['Farest']]
y_values_nearest = [item[1] for item in data_dict['Nearest']]

# Create the bar plot
bar_width = 0.2
index = np.arange(len(x_values))
plt.figure(figsize=(12, 6))

bars1 = plt.bar(index - bar_width, y_values_first, bar_width, label='First_to_find')
bars2 = plt.bar(index, y_values_farest, bar_width, label='Farest')
bars3 = plt.bar(index + bar_width, y_values_nearest, bar_width, label='Nearest')

plt.xlabel('Third Column')
plt.ylabel('Value')
plt.title('Bar Plot for Different Categories')
plt.xticks(index, x_values)
plt.legend()

# Add value labels on top of the bars
def add_value_labels(bars):
    for bar in bars:
        height = bar.get_height()
        plt.annotate('{}'.format(height),
                     xy=(bar.get_x() + bar.get_width() / 2, height),
                     xytext=(0, 3),  # 3 points vertical offset
                     textcoords="offset points",
                     ha='center', va='bottom')

add_value_labels(bars1)
add_value_labels(bars2)
add_value_labels(bars3)

plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data = [
    (24, 'First_to_find', 'CR', 855630),
    (27, 'First_to_find', 'EDD', 800991),
    (27, 'First_to_find', 'MST', 800991),
    (27, 'First_to_find', 'SLACK', 800991),
    (27, 'First_to_find', 'MANPOWER', 800991),
    (27, 'Farest', 'LPT', 800981),
    (27, 'First_to_find', 'LPT', 800925),
    (27, 'Nearest', 'MANPOWER', 800913),
    (27, 'Farest', 'MANPOWER', 800913),
    (28, 'First_to_find', 'SPT', 788516),
    (28, 'Nearest', 'MST', 769472),
    (28, 'Farest', 'MST', 769472),
    (28, 'Nearest', 'SPT', 769462),
    (28, 'Farest', 'SPT', 769462),
    (28, 'Nearest', 'EDD', 769445),
    (28, 'Farest', 'EDD', 769445),
    (28, 'Nearest', 'SLACK', 769445),
    (28, 'Farest', 'SLACK', 769445),
    (28, 'Nearest', 'CR', 769442),
    (28, 'Farest', 'CR', 769442),
    (28, 'Nearest', 'LPT', 769418)
]

# Create a dictionary to group data by the second column
data_dict = {}
for item in data:
    second_column = item[1]
    if second_column not in data_dict:
        data_dict[second_column] = []
    data_dict[second_column].append((item[2], item[3]))

# Extract x and y values for each category
categories = list(data_dict.keys())
x_values = [item[0] for item in data_dict['First_to_find']]
y_values_first = [item[1] for item in data_dict['First_to_find']]
y_values_farest = [item[1] for item in data_dict['Farest']]
y_values_nearest = [item[1] for item in data_dict['Nearest']]

# Create the bar plot
bar_width = 0.2
index = np.arange(len(x_values))
plt.figure(figsize=(12, 6))

plt.bar(index - bar_width, y_values_first, bar_width, label='First_to_find')
plt.bar(index, y_values_farest, bar_width, label='Farest')
plt.bar(index + bar_width, y_values_nearest, bar_width, label='Nearest')

plt.xlabel('Heurísticas de ordenação')
plt.ylabel('Score - Pontuação')
plt.title('Dataset b')
plt.xticks(index, x_values)
plt.legend(loc=4)
plt.tight_layout()

# Show the plot
plt.savefig('B.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data = [
(892, 'First_to_find', 'SPT', 212280),
(895, 'Farest', 'SPT', 197527),
(900, 'Nearest', 'MST', 186273),
(920, 'Nearest', 'LPT', 182793),
(894, 'Nearest', 'SPT', 182195),
(918, 'First_to_find', 'LPT', 181610),
(921, 'Farest', 'LPT', 180357),
(898, 'Farest', 'MST', 174488),
(897, 'First_to_find', 'MST', 172899),
(905, 'Nearest', 'EDD', 159455),
(909, 'Nearest', 'SLACK', 155104),
(903, 'First_to_find', 'EDD', 154636),
(908, 'Farest', 'EDD', 153959),
(907, 'First_to_find', 'SLACK', 147162),
(913, 'First_to_find', 'CR', 143640),
(907, 'Farest', 'SLACK', 141658),
(909, 'Nearest', 'CR', 140028),
(912, 'Farest', 'CR', 139636),
(902, 'Farest', 'MANPOWER', 138971),
(905, 'First_to_find', 'MANPOWER', 129650),
(899, 'Nearest', 'MANPOWER', 122929)

]

# Create a dictionary to group data by the second column
data_dict = {}
for item in data:
    second_column = item[1]
    if second_column not in data_dict:
        data_dict[second_column] = []
    data_dict[second_column].append((item[2], item[3]))

# Extract x and y values for each category
categories = list(data_dict.keys())
x_values = [item[0] for item in data_dict['First_to_find']]
y_values_first = [item[1] for item in data_dict['First_to_find']]
y_values_farest = [item[1] for item in data_dict['Farest']]
y_values_nearest = [item[1] for item in data_dict['Nearest']]

# Create the bar plot
bar_width = 0.2
index = np.arange(len(x_values))
plt.figure(figsize=(12, 6))

plt.bar(index - bar_width, y_values_first, bar_width, label='First_to_find')
plt.bar(index, y_values_farest, bar_width, label='Farest')
plt.bar(index + bar_width, y_values_nearest, bar_width, label='Nearest')

plt.xlabel('Heurísticas de ordenação')
plt.ylabel('Score - Pontuação')
plt.title('Dataset c')
plt.xticks(index, x_values)
plt.legend()
plt.tight_layout()

# Show the plot
plt.savefig('C.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data = [
(887, 'First_to_find', 'SPT', 173626),
(887, 'Nearest', 'SPT', 173626),
(887, 'Farest', 'SPT', 173626),
(887, 'First_to_find', 'LPT', 173626),
(887, 'Nearest', 'LPT', 173626),
(887, 'Farest', 'LPT', 173626),
(887, 'First_to_find', 'EDD', 173626),
(887, 'Nearest', 'EDD', 173626),
(887, 'Farest', 'EDD', 173626),
(887, 'First_to_find', 'MST', 173626),
(887, 'Nearest', 'MST', 173626),
(887, 'Farest', 'MST', 173626),
(887, 'First_to_find', 'CR', 173626),
(887, 'Nearest', 'CR', 173626),
(887, 'Farest', 'CR', 173626),
(887, 'First_to_find', 'SLACK', 173626),
(887, 'Nearest', 'SLACK', 173626),
(887, 'Farest', 'SLACK', 173626),
(887, 'First_to_find', 'MANPOWER', 173626),
(887, 'Nearest', 'MANPOWER', 173626),
(887, 'Farest', 'MANPOWER', 173626)


]

# Create a dictionary to group data by the second column
data_dict = {}
for item in data:
    second_column = item[1]
    if second_column not in data_dict:
        data_dict[second_column] = []
    data_dict[second_column].append((item[2], item[3]))

# Extract x and y values for each category
categories = list(data_dict.keys())
x_values = [item[0] for item in data_dict['First_to_find']]
y_values_first = [item[1] for item in data_dict['First_to_find']]
y_values_farest = [item[1] for item in data_dict['Farest']]
y_values_nearest = [item[1] for item in data_dict['Nearest']]

# Create the bar plot
bar_width = 0.2
index = np.arange(len(x_values))
plt.figure(figsize=(12, 6))

plt.bar(index - bar_width, y_values_first, bar_width, label='First_to_find')
plt.bar(index, y_values_farest, bar_width, label='Farest')
plt.bar(index + bar_width, y_values_nearest, bar_width, label='Nearest')

plt.xlabel('Heurísticas de ordenação')
plt.ylabel('Score - Pontuação')
plt.title('Dataset d')
plt.xticks(index, x_values)
plt.legend()
plt.tight_layout()

# Show the plot
plt.savefig('D.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data = [
    (4018, 'First_to_find', 'CR', 1610072),
    (4015, 'First_to_find', 'SLACK', 1607942),
    (4016, 'First_to_find', 'MST', 1607726),
    (4014, 'First_to_find', 'EDD', 1606530),
    (4044, 'First_to_find', 'MANPOWER', 1598597),
    (4054, 'First_to_find', 'LPT', 1598198),
    (4046, 'First_to_find', 'SPT', 1598067)

]

# Create a dictionary to group data by the second column
data_dict = {}
for item in data:
    second_column = item[1]
    if second_column not in data_dict:
        data_dict[second_column] = []
    data_dict[second_column].append((item[2], item[3]))

# Extract x and y values for each category
categories = list(data_dict.keys())
x_values = [item[0] for item in data_dict['First_to_find']]
y_values_first = [item[1] for item in data_dict['First_to_find']]

# Create the bar plot
bar_width = 0.2
index = np.arange(len(x_values))

plt.figure(figsize=(12, 6))

bars = plt.bar(index  + 0.2 - bar_width, y_values_first, bar_width, label='First_to_find')

# Add value labels on top of each bar
for bar, y_value in zip(bars, y_values_first):
    plt.text(bar.get_x() + bar.get_width() / 2, y_value, str(y_value), ha='center', va='bottom')

plt.xlabel('Heurísticas de ordenação')
plt.ylabel('Score - Pontuação')
plt.title('Dataset e')
plt.xticks(index, x_values)
plt.legend()

# Set the y-axis limits
plt.ylim(min(y_values_first)*0.999, max(y_values_first)*1.001)  # Adjust the limits as needed

plt.tight_layout()

# Show the plot
plt.savefig('E.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data = [
(16051, 'First_to_find', 'SLACK', 543471),
(16047, 'First_to_find', 'EDD', 543137),
(16032, 'First_to_find', 'CR', 543029),
(16044, 'First_to_find', 'SPT', 542843),
(16037, 'First_to_find', 'LPT', 542258),
(16035, 'First_to_find', 'MST', 541974),
(16033, 'First_to_find', 'MANPOWER', 541664)

]

# Create a dictionary to group data by the second column
data_dict = {}
for item in data:
    second_column = item[1]
    if second_column not in data_dict:
        data_dict[second_column] = []
    data_dict[second_column].append((item[2], item[3]))

# Extract x and y values for each category
categories = list(data_dict.keys())
x_values = [item[0] for item in data_dict['First_to_find']]
y_values_first = [item[1] for item in data_dict['First_to_find']]

# Create the bar plot
bar_width = 0.2
index = np.arange(len(x_values))

plt.figure(figsize=(12, 6))

bars = plt.bar(index  + 0.2 - bar_width, y_values_first, bar_width, label='First_to_find')

# Add value labels on top of each bar
for bar, y_value in zip(bars, y_values_first):
    plt.text(bar.get_x() + bar.get_width() / 2, y_value, str(y_value), ha='center', va='bottom')

plt.xlabel('Heurísticas de ordenação')
plt.ylabel('Score - Pontuação')
plt.title('Dataset f')
plt.xticks(index, x_values)
plt.legend()

# Set the y-axis limits
plt.ylim(min(y_values_first)*0.999, max(y_values_first)*1.001)  # Adjust the limits as needed

plt.tight_layout()

# Show the plot
plt.savefig('F.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data = [
(0, 'First_to_find', 'SPT', 33),
(1, 'Nearest', 'SPT', 30),
(1, 'Farest', 'SPT', 30),
(1, 'First_to_find', 'LPT', 30),
(1, 'Nearest', 'LPT', 30),
(1, 'Farest', 'LPT', 30),
(1, 'First_to_find', 'EDD', 30),
(1, 'Nearest', 'EDD', 30),
(1, 'Farest', 'EDD', 30),
(1, 'First_to_find', 'MST', 30),
(1, 'Nearest', 'MST', 30),
(1, 'Farest', 'MST', 30),
(1, 'First_to_find', 'CR', 30),
(1, 'Nearest', 'CR', 30),
(1, 'Farest', 'CR', 30),
(1, 'First_to_find', 'SLACK', 30),
(1, 'Nearest', 'SLACK', 30),
(1, 'Farest', 'SLACK', 30),
(0, 'First_to_find', 'MANPOWER', 33),
(0, 'Nearest', 'MANPOWER', 33),
(0, 'Farest', 'MANPOWER', 33)


]

# Create a dictionary to group data by the second column
data_dict = {}
for item in data:
    second_column = item[1]
    if second_column not in data_dict:
        data_dict[second_column] = []
    data_dict[second_column].append((item[2], item[3]))

# Extract x and y values for each category
categories = list(data_dict.keys())
x_values = [item[0] for item in data_dict['First_to_find']]
y_values_first = [item[1] for item in data_dict['First_to_find']]
y_values_farest = [item[1] for item in data_dict['Farest']]
y_values_nearest = [item[1] for item in data_dict['Nearest']]

# Create the bar plot
bar_width = 0.2
index = np.arange(len(x_values))
plt.figure(figsize=(12, 6))

plt.bar(index - bar_width, y_values_first, bar_width, label='First_to_find')
plt.bar(index, y_values_farest, bar_width, label='Farest')
plt.bar(index + bar_width, y_values_nearest, bar_width, label='Nearest')

plt.xlabel('Heurísticas de ordenação')
plt.ylabel('Score - Pontuação')
plt.title('Dataset a')
plt.xticks(index, x_values)
plt.legend(loc=4)
plt.tight_layout()

# Show the plot
plt.savefig('A.png')
plt.show()
